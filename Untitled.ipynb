# %%
import numpy as np
import pandas as pd

# %%
dict_df = pd.read_excel("BIG TIME.xlsx", sheetname=None)
dict_df.keys()
# Out:
# dict_keys(['Storage_wxadj', 'WM Ind', 'Dates', 'Pwr', 'RenGen Index', 'NG Prices', 'Imbalance'])

# %%
dict_df['Storage_wxadj']
# Out:
#            Date  Storage(adj wx)   positive= bearish
# 0    2011-06-19         1.537004  negative = bullish
# 1    2011-06-20         1.853621                 NaN
# 2    2011-06-21         1.192188                 NaN
# 3    2011-06-22         0.246267                 NaN
# 4    2011-06-23        -1.122011                 NaN
# 5    2011-06-24        -2.124403                 NaN
# 6    2011-06-25        -2.472184                 NaN
# 7    2011-06-26        -2.741732                 NaN
# 8    2011-06-27        -2.683507                 NaN
# 9    2011-06-28        -2.178810                 NaN
# 10   2011-06-29        -1.425220                 NaN
# 11   2011-06-30        -0.384702                 NaN
# 12   2011-07-01         0.351009                 NaN
# 13   2011-07-02         1.390127                 NaN
# 14   2011-07-03         1.733111                 NaN
# 15   2011-07-04         1.746256                 NaN
# 16   2011-07-05         2.744544                 NaN
# ...
